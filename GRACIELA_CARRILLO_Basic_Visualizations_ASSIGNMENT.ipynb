# %% [markdown]
# <a href="https://colab.research.google.com/github/gracecarrillo/KAPLAN_PM-617/blob/master/GRACIELA_CARRILLO_Basic_Visualizations_ASSIGNMENT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # Data Science - Intro to Pandas
# ---
# # 06 - Basic Visualizations
# ---

# %% [markdown]
# ##STOP! BEFORE GOING ANY FURTHER...
#
#
# 1. Click "File" at the top.
# 2. Then, "Save a Copy in Drive."
# 3. Change the file name to "FIRSTNAME_LASTNAME_1_2"
#
# Now you have a copy of this notebook in your Drive account. This is the copy you'll edit and submit. Be sure to do this for ***every*** assignment!

# %% [markdown]
# ### Import pandas & matplotlib

# %%
import pandas as pd, matplotlib.pyplot as plt
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ### Import the data in the CSV file
# You can find the data [here](https://raw.githubusercontent.com/plotly/datasets/master/data.csv). Should have a shape of (150000,11). Use this [resource](https://github.com/plotly/datasets/blob/master/data_dictionary.csv) for context.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/data.csv')
df.shape
# Out:
# (150000, 11)

# %% [markdown]
# ### Quickly inspect the head

# %%
df.head()
# Out:
#    SeriousDlqin2yrs  ...  NumberOfDependents
# 0                 1  ...                 2.0
# 1                 0  ...                 1.0
# 2                 0  ...                 0.0
# 3                 0  ...                 0.0
# 4                 0  ...                 0.0
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Inspect the tail

# %%
df.tail()
# Out:
#         SeriousDlqin2yrs  ...  NumberOfDependents
# 149995                 0  ...                 0.0
# 149996                 0  ...                 2.0
# 149997                 0  ...                 0.0
# 149998                 0  ...                 0.0
# 149999                 0  ...                 0.0
#
# [5 rows x 11 columns]

# %% [markdown]
# ### What is the shape of the DataFrame? Does it correspond to what we expected?

# %%
df.shape
# Out:
# (150000, 11)

# %% [markdown]
# ### Do you need to change the index?

# %%
# No

# %% [markdown]
# ### Missing values?
# You don't need to fill in these missing values, but don't forget that they're there!

# %%
df.isnull().sum()
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# NumberOfTime30-59DaysPastDueNotWorse        0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# NumberOfTimes90DaysLate                     0
# NumberRealEstateLoansOrLines                0
# NumberOfTime60-89DaysPastDueNotWorse        0
# NumberOfDependents                       3924
# dtype: int64

# %% [markdown]
# ### Out of the 11 features, which are discrete and which are continuous?
#
#
# ---

# %% [markdown]
# Continuous: age, DebtRatio, MonthlyIncome, RevolvingUtilizationOfUnsecuredLines
#
# Discrete: All the others

# %%
df['NumberOfTime30-59DaysPastDueNotWorse'].describe()
# Out:
# count    150000.000000
# mean          0.421033
# std           4.192781
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          98.000000
# Name: NumberOfTime30-59DaysPastDueNotWorse, dtype: float64

# %% [markdown]
# ### Plot each feature with the appropriate visualization

# %% [markdown]
# #### Histograms

# %%
continuous_columns = ['age', 'DebtRatio', 'MonthlyIncome', 'RevolvingUtilizationOfUnsecuredLines']
df[continuous_columns].hist(figsize=(10,11));

# %% [markdown]
# #### Bar charts

# %%
def category_count_plot(col, figsize=(8,4)):
    """
    Plots a simple bar chart of the total count for each category in the column specified.
    A figure size can optionally be specified.
    """
    plt.figure(figsize=figsize)
    df[col].value_counts().plot(kind='bar')
    plt.title(col)
    plt.xticks(rotation=0)
    plt.show()

  
for col in ['SeriousDlqin2yrs', 'NumberOfTime30-59DaysPastDueNotWorse',
                    'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
                    'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
                    'NumberOfDependents']:
    category_count_plot(col, figsize=(4,3))
    print(df[col].value_counts())
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64
# 0     126018
# 1      16033
# 2       4598
# 3       1754
# 4        747
# 5        342
# 98       264
# 6        140
# 7         54
# 8         25
# 9         12
# 96         5
# 10         4
# 12         2
# 13         1
# 11         1
# Name: NumberOfTime30-59DaysPastDueNotWorse, dtype: int64
# 6     13614
# 7     13245
# 5     12931
# 8     12562
# 4     11609
# 9     11355
# 10     9624
# 3      9058
# 11     8321
# 12     7005
# 2      6666
# 13     5667
# 14     4546
# 1      4438
# 15     3645
# 16     3000
# 17     2370
# 0      1888
# 18     1874
# 19     1433
# 20     1169
# 21      864
# 22      685
# 23      533
# 24      422
# 25      337
# 26      239
# 27      194
# 28      150
# 29      114
# 30       88
# 31       74
# 32       52
# 33       47
# 34       35
# 35       27
# 36       18
# 38       13
# 40       10
# 39        9
# 45        8
# 43        8
# 42        8
# 37        7
# 48        6
# 41        4
# 54        4
# 49        4
# 46        3
# 52        3
# 51        2
# 56        2
# 57        2
# 50        2
# 47        2
# 44        2
# 53        1
# 58        1
# Name: NumberOfOpenCreditLinesAndLoans, dtype: int64
# 0     141662
# 1       5243
# 2       1555
# 3        667
# 4        291
# 98       264
# 5        131
# 6         80
# 7         38
# 8         21
# 9         19
# 10         8
# 11         5
# 96         5
# 13         4
# 12         2
# 14         2
# 15         2
# 17         1
# Name: NumberOfTimes90DaysLate, dtype: int64
# 0     56188
# 1     52338
# 2     31522
# 3      6300
# 4      2170
# 5       689
# 6       320
# 7       171
# 8        93
# 9        78
# 10       37
# 11       23
# 12       18
# 13       15
# 14        7
# 15        7
# 16        4
# 17        4
# 25        3
# 18        2
# 19        2
# 20        2
# 23        2
# 32        1
# 21        1
# 26        1
# 29        1
# 54        1
# Name: NumberRealEstateLoansOrLines, dtype: int64
# 0     142396
# 1       5731
# 2       1118
# 3        318
# 98       264
# 4        105
# 5         34
# 6         16
# 7          9
# 96         5
# 8          2
# 11         1
# 9          1
# Name: NumberOfTime60-89DaysPastDueNotWorse, dtype: int64
# 0.0     86902
# 1.0     26316
# 2.0     19522
# 3.0      9483
# 4.0      2862
# 5.0       746
# 6.0       158
# 7.0        51
# 8.0        24
# 9.0         5
# 10.0        5
# 13.0        1
# 20.0        1
# Name: NumberOfDependents, dtype: int64

# %% [markdown]
# #### Scatterplots

# %%
for var in continuous_columns[1:]:
  df.plot.scatter(x='age', y=[var],c='Red');

# %% [markdown]
# Relationship?
#
# ---

# %% [markdown]
# No appareant relationship

# %% [markdown]
# #### Boxplots

# %%
for var in continuous_columns:
  df.boxplot(column= var)
  plt.show()

# %% [markdown]
# Any outliers?
#
#
# ---
# Several in every continuous variable

# %% [markdown]
# ### Submit your assignment notebook! (Make sure you've changed the name to FIRSTNAME_LASTNAME_1_2):
#
# 1.  Click the Share button in the upper-right hand corner of the notebook.
# 2.  Get the shareable link.
# 3.  Set condition to: "Anyone with the link can comment."
# 4.  TBD
#
#
# ---
